# %%
from gurobipy import *  # import the optimize solver Gurobi

# %%
number_of_year = 25 # Set the index j for total number of year
number_of_month = 12 # Set the index i for total number of year 
m = Model() # Import and create the model
# Out:
# Using license file C:\Users\chaoz\gurobi_licence\gurobi.lic
# Academic license - for non-commercial use only

# %%
# Set the input Parameter: 
actual_amount = 850000  # The house original price
end_payment = 50000 # Ending payment/Balloon payment
monthly_rate = 0.05 / 12 # Monthly interest rate
yearly_increase = 1.05 # Yearly increase in monthly payments

# %%
# Set the Variable list: Monthly payment for year 1
# Set the variable to continuous number
x1 = m.addVar(vtype=GRB.CONTINUOUS, name='x1')

# %%
# Caculate monthly payment for year j 
x = [0] * 25
for j in range(number_of_year):
    if j >= 1: 
        x[j] = yearly_increase * x[j - 1]
    else:
        x[j] = x1

# %%
# Caculate ending balance after month i
Q = []
for j in range(number_of_year):
    for i in range(number_of_month):
        if j == i == 0:
            start_amount = actual_amount
        else:
            start_amount = Q[-1]
        Q.append(start_amount*(1 + monthly_rate) - x[j])

# %%
# Set the Minimize Obijective: Total Revenue
m.setObjective( x1 ,  GRB.MINIMIZE)

# %%
# Set Non Negative month payment
c1 = m.addConstr(x1  >= 0)

# %%
# Amount remaining after balloon payment should be fully repaid after 25 years
c2 = m.addConstr(Q[-1] - end_payment == 0)

# %%
# Run the optimize solver
m.optimize()
# Out:
# Gurobi Optimizer version 9.0.1 build v9.0.1rc0 (win64)
# Optimize a model with 2 rows, 1 columns and 2 nonzeros
# Model fingerprint: 0x3bb4e9f5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+06, 3e+06]
# Presolve removed 2 rows and 1 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8996098e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.04 seconds
# Optimal objective  2.899609833e+03

# %%
# Get the Optimal Solution for X
m.printAttr('X')
# Out:
#     Variable            X
# -------------------------
#           x1      2899.61

# %%
# Get the monthly payment for each year
x = [0] * 25
for j in range(number_of_year):
    if j >= 1: 
        x[j] = yearly_increase * x[j - 1]
    else:
        x[j] = m.X[0]
    print('Monthly payment for %d year:'%(j + 1), round(x[j], 2))
# Out:
# Monthly payment for 1 year: 2899.61
# Monthly payment for 2 year: 3044.59
# Monthly payment for 3 year: 3196.82
# Monthly payment for 4 year: 3356.66
# Monthly payment for 5 year: 3524.49
# Monthly payment for 6 year: 3700.72
# Monthly payment for 7 year: 3885.75
# Monthly payment for 8 year: 4080.04
# Monthly payment for 9 year: 4284.04
# Monthly payment for 10 year: 4498.25
# Monthly payment for 11 year: 4723.16
# Monthly payment for 12 year: 4959.32
# Monthly payment for 13 year: 5207.28
# Monthly payment for 14 year: 5467.65
# Monthly payment for 15 year: 5741.03
# Monthly payment for 16 year: 6028.08
# Monthly payment for 17 year: 6329.48
# Monthly payment for 18 year: 6645.96
# Monthly payment for 19 year: 6978.26
# Monthly payment for 20 year: 7327.17
# Monthly payment for 21 year: 7693.53
# Monthly payment for 22 year: 8078.2
# Monthly payment for 23 year: 8482.11
# Monthly payment for 24 year: 8906.22
# Monthly payment for 25 year: 9351.53

# %%
# Get the ending balance after month i
Q = []
for j in range(number_of_year):
    print('Ending balance amount of %d year is '%(j+1))
    for i in range(number_of_month):
        if j == i == 0:
            start_amount = actual_amount
        else:
            start_amount = Q[-1]
        Q.append(start_amount*(1 + monthly_rate) - x[j])
        print('   %d month : '%(i+1), round((start_amount*(1 + monthly_rate) - x[j]), 2))
# Out:
# Ending balance amount of 1 year is
#    1 month :  850642.06
#    2 month :  851286.79
#    3 month :  851934.21
#    4 month :  852584.32
#    5 month :  853237.15
#    6 month :  853892.69
#    7 month :  854550.97
#    8 month :  855211.99
#    9 month :  855875.76
#    10 month :  856542.3
#    11 month :  857211.62
#    12 month :  857883.72
# Ending balance amount of 2 year is
#    1 month :  858413.65
#    2 month :  858945.78
#    3 month :  859480.13
#    4 month :  860016.71
#    5 month :  860555.52
#    6 month :  861096.58
#    7 month :  861639.89
#    8 month :  862185.47
#    9 month :  862733.32
#    10 month :  863283.45
#    11 month :  863835.87
#    12 month :  864390.6
# Ending balance amount of 3 year is
#    1 month :  864795.41
#    2 month :  865201.9
#    3 month :  865610.09
#    4 month :  866019.98
#    5 month :  866431.57
#    6 month :  866844.89
#    7 month :  867259.92
#    8 month :  867676.68
#    9 month :  868095.18
#    10 month :  868515.43
#    11 month :  868937.42
#    12 month :  869361.17
# Ending balance amount of 4 year is
#    1 month :  869626.85
#    2 month :  869893.63
#    3 month :  870161.53
#    4 month :  870430.54
#    5 month :  870700.68
#    6 month :  870971.93
#    7 month :  871244.32
#    8 month :  871517.85
#    9 month :  871792.51
#    10 month :  872068.32
#    11 month :  872345.28
#    12 month :  872623.39
# Ending balance amount of 5 year is
#    1 month :  872734.82
#    2 month :  872846.72
#    3 month :  872959.09
#    4 month :  873071.93
#    5 month :  873185.23
#    6 month :  873299.01
#    7 month :  873413.26
#    8 month :  873527.99
#    9 month :  873643.2
#    10 month :  873758.88
#    11 month :  873875.05
#    12 month :  873991.7
# Ending balance amount of 6 year is
#    1 month :  873932.62
#    2 month :  873873.29
#    3 month :  873813.71
#    4 month :  873753.88
#    5 month :  873693.8
#    6 month :  873633.47
#    7 month :  873572.89
#    8 month :  873512.06
#    9 month :  873450.98
#    10 month :  873389.64
#    11 month :  873328.04
#    12 month :  873266.19
# Ending balance amount of 7 year is
#    1 month :  873019.04
#    2 month :  872770.87
#    3 month :  872521.66
#    4 month :  872271.41
#    5 month :  872020.12
#    6 month :  871767.79
#    7 month :  871514.4
#    8 month :  871259.95
#    9 month :  871004.45
#    10 month :  870747.88
#    11 month :  870490.24
#    12 month :  870231.53
# Ending balance amount of 8 year is
#    1 month :  869777.45
#    2 month :  869321.48
#    3 month :  868863.61
#    4 month :  868403.83
#    5 month :  867942.14
#    6 month :  867478.52
#    7 month :  867012.98
#    8 month :  866545.49
#    9 month :  866076.05
#    10 month :  865604.66
#    11 month :  865131.3
#    12 month :  864655.98
# Ending balance amount of 9 year is
#    1 month :  863974.66
#    2 month :  863290.51
#    3 month :  862603.51
#    4 month :  861913.65
#    5 month :  861220.91
#    6 month :  860525.29
#    7 month :  859826.77
#    8 month :  859125.33
#    9 month :  858420.98
#    10 month :  857713.69
#    11 month :  857003.45
#    12 month :  856290.26
# Ending balance amount of 10 year is
#    1 month :  855359.88
#    2 month :  854425.64
#    3 month :  853487.5
#    4 month :  852545.45
#    5 month :  851599.48
#    6 month :  850649.56
#    7 month :  849695.69
#    8 month :  848737.84
#    9 month :  847776.0
#    10 month :  846810.15
#    11 month :  845840.28
#    12 month :  844866.37
# Ending balance amount of 11 year is
#    1 month :  843663.49
#    2 month :  842455.59
#    3 month :  841242.67
#    4 month :  840024.69
#    5 month :  838801.63
#    6 month :  837573.48
#    7 month :  836340.21
#    8 month :  835101.8
#    9 month :  833858.23
#    10 month :  832609.48
#    11 month :  831355.53
#    12 month :  830096.35
# Ending balance amount of 12 year is
#    1 month :  828595.77
#    2 month :  827088.94
#    3 month :  825575.82
#    4 month :  824056.4
#    5 month :  822530.66
#    6 month :  820998.55
#    7 month :  819460.06
#    8 month :  817915.16
#    9 month :  816363.82
#    10 month :  814806.02
#    11 month :  813241.73
#    12 month :  811670.92
# Ending balance amount of 13 year is
#    1 month :  809845.6
#    2 month :  808012.68
#    3 month :  806172.11
#    4 month :  804323.88
#    5 month :  802467.95
#    6 month :  800604.28
#    7 month :  798732.85
#    8 month :  796853.62
#    9 month :  794966.56
#    10 month :  793071.64
#    11 month :  791168.82
#    12 month :  789258.08
# Ending balance amount of 14 year is
#    1 month :  787079.0
#    2 month :  784890.85
#    3 month :  782693.58
#    4 month :  780487.16
#    5 month :  778271.54
#    6 month :  776046.7
#    7 month :  773812.58
#    8 month :  771569.15
#    9 month :  769316.37
#    10 month :  767054.21
#    11 month :  764782.62
#    12 month :  762501.57
# Ending balance amount of 15 year is
#    1 month :  759937.63
#    2 month :  757363.01
#    3 month :  754777.66
#    4 month :  752181.54
#    5 month :  749574.6
#    6 month :  746956.8
#    7 month :  744328.09
#    8 month :  741688.43
#    9 month :  739037.77
#    10 month :  736376.06
#    11 month :  733703.26
#    12 month :  731019.33
# Ending balance amount of 16 year is
#    1 month :  728037.17
#    2 month :  725042.57
#    3 month :  722035.5
#    4 month :  719015.9
#    5 month :  715983.72
#    6 month :  712938.91
#    7 month :  709881.41
#    8 month :  706811.16
#    9 month :  703728.13
#    10 month :  700632.25
#    11 month :  697523.47
#    12 month :  694401.74
# Ending balance amount of 17 year is
#    1 month :  690965.59
#    2 month :  687515.13
#    3 month :  684050.29
#    4 month :  680571.02
#    5 month :  677077.25
#    6 month :  673568.92
#    7 month :  670045.97
#    8 month :  666508.34
#    9 month :  662955.98
#    10 month :  659388.81
#    11 month :  655806.78
#    12 month :  652209.82
# Ending balance amount of 18 year is
#    1 month :  648281.4
#    2 month :  644336.62
#    3 month :  640375.39
#    4 month :  636397.67
#    5 month :  632403.36
#    6 month :  628392.42
#    7 month :  624364.76
#    8 month :  620320.32
#    9 month :  616259.03
#    10 month :  612180.82
#    11 month :  608085.61
#    12 month :  603973.35
# Ending balance amount of 19 year is
#    1 month :  599511.64
#    2 month :  595031.35
#    3 month :  590532.39
#    4 month :  586014.69
#    5 month :  581478.16
#    6 month :  576922.73
#    7 month :  572348.32
#    8 month :  567754.84
#    9 month :  563142.23
#    10 month :  558510.4
#    11 month :  553859.27
#    12 month :  549188.76
# Ending balance amount of 20 year is
#    1 month :  544149.88
#    2 month :  539090.0
#    3 month :  534009.04
#    4 month :  528906.91
#    5 month :  523783.52
#    6 month :  518638.78
#    7 month :  513472.6
#    8 month :  508284.9
#    9 month :  503075.59
#    10 month :  497844.57
#    11 month :  492591.75
#    12 month :  487317.04
# Ending balance amount of 21 year is
#    1 month :  481654.0
#    2 month :  475967.37
#    3 month :  470257.04
#    4 month :  464522.91
#    5 month :  458764.9
#    6 month :  452982.89
#    7 month :  447176.79
#    8 month :  441346.5
#    9 month :  435491.91
#    10 month :  429612.94
#    11 month :  423709.46
#    12 month :  417781.39
# Ending balance amount of 22 year is
#    1 month :  411443.94
#    2 month :  405080.09
#    3 month :  398689.71
#    4 month :  392272.72
#    5 month :  385828.98
#    6 month :  379358.4
#    7 month :  372860.85
#    8 month :  366336.24
#    9 month :  359784.43
#    10 month :  353205.33
#    11 month :  346598.81
#    12 month :  339964.77
# Ending balance amount of 23 year is
#    1 month :  332899.18
#    2 month :  325804.14
#    3 month :  318679.54
#    4 month :  311525.26
#    5 month :  304341.17
#    6 month :  297127.14
#    7 month :  289883.06
#    8 month :  282608.79
#    9 month :  275304.21
#    10 month :  267969.2
#    11 month :  260603.62
#    12 month :  253207.35
# Ending balance amount of 24 year is
#    1 month :  245356.16
#    2 month :  237472.26
#    3 month :  229555.51
#    4 month :  221605.77
#    5 month :  213622.91
#    6 month :  205606.78
#    7 month :  197557.25
#    8 month :  189474.19
#    9 month :  181357.44
#    10 month :  173206.88
#    11 month :  165022.36
#    12 month :  156803.73
# Ending balance amount of 25 year is
#    1 month :  148105.55
#    2 month :  139371.12
#    3 month :  130600.3
#    4 month :  121792.94
#    5 month :  112948.88
#    6 month :  104067.97
#    7 month :  95150.05
#    8 month :  86194.98
#    9 month :  77202.59
#    10 month :  68172.74
#    11 month :  59105.26
#    12 month :  50000.0
